# %%
from eda_helper import see_dir_size, EDA_helper

data = EDA_helper('stage_pre_train')

# %% [markdown]
# ## Basic parameters

# %%
size = data.size
csvf = data.csvf
dcms = data.dcms
imgs = data.imgs

# %%
imgs
# Out:
# [array([[ 26,  26,  27, ...,  24,  24,  25],
#         [ 25,  26,  27, ...,  24,  24,  26],
#         [ 23,  24,  25, ...,  26,  26,  27],
#         ...,
#         [561, 558, 548, ..., 179, 203, 246],
#         [563, 558, 546, ..., 182, 195, 227],
#         [534, 527, 519, ..., 217, 223, 244]], dtype=uint16),
#  array([[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         ...,
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024]], dtype=int16),
#  array([[-2000, -2000, -2000, ..., -2000, -2000, -2000],
#         [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#         [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#         ...,
#         [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#         [-2000, -2000, -2000, ..., -2000, -2000, -2000],
#         [-2000, -2000, -2000, ..., -2000, -2000, -2000]], dtype=int16),
#  array([[26, 24, 23, ..., 25, 25, 24],
#         [27, 26, 26, ..., 25, 25, 26],
#         [27, 27, 26, ..., 25, 26, 26],
#         ...,
#         [22, 23, 22, ..., 20, 20, 20],
#         [23, 25, 24, ..., 21, 21, 18],
#         [24, 24, 25, ..., 22, 19, 19]], dtype=uint16),
#  array([[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         ...,
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#         [-1024, -1024, -1024, ..., -1024, -1024, -1024]], dtype=int16)]

# %% [markdown]
# ## step 1. Get Original Daicom Images

# %%
data.show_imgs(imgs)

# %% [markdown]
# ## step 2. Convert to Hounsfield Unit(HU)

# %%
hu_imgs = data.get_hu_imgs()
data.show_imgs(hu_imgs)

# %%
data.show_hu_graph(0)

# %% [markdown]
# ## step 3. CT Windowing
#
# ### Brain windows
# * used to view a range of densities close to the average density of the soft tissues of the brain. 'Bone windows' are used to emphasise a narrow range of densities close to the density of bone.

# %%
windowed_imgs = data.get_window_imgs()
data.show_imgs(windowed_imgs)

# %% [markdown]
# ## step 4. Check Label

# %%
data.plot_label()

# %% [markdown]
# ## step 5. Check label each patient CT image

# %%
data.show_sub_label(2)

# %%
for i in range(size):
    data.show_sub_label(i)
